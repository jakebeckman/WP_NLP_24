# %% [markdown]
# # Project 1

# %% [markdown]
# ## Overview

# %% [markdown]
# For this project, we used two python packages to analyze twitter sentiment on Biden, Trump, and Kamala. We chose to analyze political topics because of the upcoming election and therefore increasing relevance on twitter. We are interested to see how each of these candidates are viewd by twitter users to get some insight into possible election outcomes.

# %% [markdown]
# ## Importing Data

# %% [markdown]
# We could not get our twitter API to work, so we pulled our data from https://www.kaggle.com/datasets/fastcurious/twitter-dataset-february-2024?resource=download. We load our data in a json format to be processed for sentiment analysis.

# %%
# Import data from json file
import json
with open(r"C:\Users\JakeBeckman\Downloads\dataset_tweet-scraper_2024-03-04_15-49-10-416.json",'r',encoding='utf-8') as f:
    content = json.load(f)

# %%
# Function that cleans data to include only text from tweets
def get_text(tweets:list)->list:
    text = []
    for tweet in tweets:
        if tweet['type']=='tweet':
            text.append(tweet['text'])
    return text

# %%
# Function that pulls tweets with the specified topic
def pull_topic(tweets:list,topic:str)->list:
    tweets_ontopic=[]
    for tweet in tweets:
        if topic.lower() in str(tweet.lower()):
            tweets_ontopic.append(tweet)
    return tweets_ontopic

# %%
# View first 4 tweets in the dataset
text = get_text(content)
print(text[:4])
# Out:
# ['#Demographics is destiny. The future ONLY belongs to those able and willing to conduct #massdeportations, STOP the #BorderInvasion.🇺🇸', '“@Gemini failed to conduct due diligence on an unregulated third party, later accused of massive fraud, harming Earn customers who were suddenly unable to access their assets after Genesis Global Capital experienced a financial meltdown.” https://t.co/fb9qSOHSqT', '@BidensWins 🤣 did Hunter conduct the poll ?', '@visegrad24 So he can give them more orders to conduct October 7th type attacks.']

# %% [markdown]
# ## Processing the data

# %%
from nltk.stem import WordNetLemmatizer
from nltk import word_tokenize
from nltk.corpus import stopwords
from nltk.tokenize import RegexpTokenizer

# %%
stopwords_list = list(stopwords.words('english'))
tokenizer = RegexpTokenizer(r'\w+')

lemmatizer = WordNetLemmatizer()

tokenized_tweets = [tokenizer.tokenize(i) for i in text]

processed_tokenized_tweets=[]
for tweet in tokenized_tweets:
    processed_tokenized_tweets.append([lemmatizer.lemmatize(word.lower()) for word in tweet if word.lower() not in stopwords_list])

final_tweets = [' '.join(words) for words in processed_tokenized_tweets]
final_tweets
# Out:
# ['demographic destiny future belongs able willing conduct massdeportations stop borderinvasion',
#  'gemini failed conduct due diligence unregulated third party later accused massive fraud harming earn customer suddenly unable access asset genesis global capital experienced financial meltdown http co fb9qsohsqt',
#  'bidenswins hunter conduct poll',
#  'visegrad24 give order conduct october 7th type attack',
#  'anniebecky haha conduct mongoose status lub ummmm lady tiiiiimeeee',
#  'robertkennedyjr western intelligence asset got caught trying conduct color revolution behest mi6 cia nothing noble courageous far right nationalist racist yet regurgitate champion democracy',
#  'schiefertomtom think want excuse appalling conduct good people narrative',
#  'unapologt haaretzcom fighting terrorist organisation appeased would conduct terrorist attack take hostage',
#  'paulkrugman uh airport asia europe lightyears beyond term cleanliness conduct quality food restaurant etc',
#  'opinion establishment need impose martial law conduct poll election heavy security everything crystal clear',
#  'stay vigilant conduct thorough research welcome optimistic path ahead numbersprotocol numbersprotocol telegram community http co nznjlvj27f',
#  'leading spinal surgeon botched operation left patient losing blood devastating pain damning investigation report reveals finding uncovered unacceptable unprofessional conduct patient staff 20 year career helenavesty http co yzmy8ocwli',
#  'obliterating mean sustain life infrastructure conduct life future threatrn continued existence part definition genocide',
#  '1984_nate dpgbehler rogerecoff the_idol_killer nate comment made sense say disagreement mean care silly point obvious provisionists conduct online ministry reveals little concern warren view god concerned',
#  'putin different george w bush netanyahu transparent investigation think united nation going conduct thing russia mind pick biased organization look anything involving russia',
#  'ss6_fineto ozdemiroglunaz compared claiming sight blood damage indication luffy tooken damage panel panel kizaru temporarily stunned face glass outfit still tip top condition',
#  'painful single condition one نمشؾ h20 ٺون 888n',
#  'veturi2011 enraged_indian per caput income show real condition economy though 5th largest economy world http co 0vypgx8rqv',
#  'seldeednow jowilso99859694 liberty noun condition free oppressive restriction control government power mom version liberty literal liberty imposing belief moral others',
#  'star_investor reason tanked act god wildfire driven 50 60mph wind condition throughout southern u stretch way wyoming',
#  'parenting tip spouse dislike certain genre movie condition child like genre never watch alone 2018 han solo premier 2024 dune 2 premier http co agfczwzte9',
#  'ryannpike bonus condition see zary currently pace hit top 3 among forward could get 3rd rookie team forward slot lot competition need pick scoring pace little hit 20 goal clause http co 1ix2mgxahz',
#  'existence often feel like chronic condition prompting u seek various form relief coping mechanism endure tolerate sheer fact quite dispiriting time unbearably tough',
#  'time condition sleep doom pio voice',
#  'raymond82310289 try telling guy currently hospital almeria blood clot lung leg critical condition doctor trying level best treat',
#  'truth_matters20 yeah life threatening health condition birth definitely make believe god bullshit',
#  'taesoothe furthermore one doctor know exactly condition cannot',
#  'pigskinjunkie91 yup condition random 2nd round pick though still laughing people really think bad gm',
#  'bigstepperpay coming tomorrow ufc298 announced post fight conference',
#  'register aafp national conference registration 50 may 16th waiting http co fjsjttmisv',
#  'mulletyno bignatetwelve filtered p5 conference',
#  'nctm regional conference seattle awesome great learn recharge battery little reflection http co oa3p9ly8dc nctm nctmsea24 mathigonorg',
#  'affleckquine death taking light israel genocide maybe plan maybe even dead wife look traumatised hour later giving press conference know way israel getting away murder bit time',
#  'northern_nazgul vikingdm1 dustbaker 1 savior hardly even make playoff let alone win playoff game everyone atleast conference championship game kirk last two playoff game got embarrassed niner got outplayed daniel jones',
#  'persuaded 4 palestinian 4 jewish student meet room try come compromise disastrous motion nu conference ban funding zionist group naive son say notice thing',
#  'sheridanblog waiving saric picking cousin probably difference 2nd round conference final',
#  'rebelbythought use parody account build case press conference',
#  'killstrike8234 antman5mvp propelstalk aside wolf matchup would prefer team think pel would like avoid going insane western conference wait post asb race playoff feel like every game hella competitive',
#  'response dixon press conference scott campaign called feigned concern dixon want take baltimore city back failed broken crime policy past including zero tolerance policing terrorized black community',
#  'billackman harvard blame rather hateful conduct penetrating echo chamber wealthy elite victim class',
#  'theyearofthej patriotxv11 newyorkstateag would looked like dictator went corruption golf course safest place conduct top secret business switch venue fairly quickly see people distance',
#  'pakistan significance taking oath seems undermined prevalent culture corruption disregard ethical conduct among politician judge general',
#  'sabra_the genuine negotiation requires trust lacking hamas conduct',
#  'davidvick5 inherently decent people conduct well',
#  'mean violated code conduct lied witness stand disqualified trump case passed another county handed prosecutor red county refuse prosecute georgia charge one one wanted bring several prosecutor turned mean case lost job probably ability practice law georgia could even held contempt lying serve time wait see play russian collusion remember',
#  'live dualistic reality would opposite ocd also duty compassionate order dco balance people consistently bring wanted thought order tend conduct practice hygiene due diligence math social medium together powerful tool engaging mind impacting social change done repetitively significantly boost person daily activity social interaction desk source source',
#  'many thanks douglascollege occupational health amp safety committee conduct conflict de escalation training last week commitment safe amp harmonious work environment truly inspiring grateful opportunity conflictresolution douglascollege http co 05chn8dr0k',
#  'bosnerdley governor kemp fire two unbecoming conduct theft public fund idiotic baseless harassment via multiple lawsuit',
#  'matthew_ds9 right jesus definitely never anything show u care conduct house',
#  'jakewsimons genuine negotiation requires trust lacking hamas conduct',
#  'prosecutor reject claim unfairness trump classified document case never case american history former official engaged conduct remotely similar trump http co v7hfbrmhnr',
#  'one key suggestion report consolidation code conduct bureau economic financial crime commission independent corrupt practice related offence commission single agency',
#  'frburgat le_crif dray hollande macron',
#  'rational sadly seen anything rational even constitutionally conforming conduct wh eg like honoring order student loan forgiveness scotus rational allowing fentanyl human trafficking minor unable locate monitor freely cross border allowing unvetted unvaccinated undocumented potential terrorist hostile nation country see rational',
#  'change conduct state even today soul نمشؾ w77 ٺون fvf',
#  'yekunoamlak12 militant terrorist fano civilian hit drone strike curse amhara civilian give ticket abiy conduct drone strike',
#  'join kevin march 22 host session conduct transact sql code review best part one four talk register http co wabcemvd46 databasemanagement sqlbits http co pwmj5vpu9s',
#  'dickson87 webb issue concern conduct amp try punish win',
#  'flying today could tomorrow round ii would focus question israel conduct war gaza question marc lamont hill otherwise well good speaker know subject imo botched conversation',
#  'jul101vie reactively well sure casual sex conducted safely longer risky behaviour reason work teaching abstinence school instead safe responsible sexual conduct however continue risky behaviour human sex young',
#  'make stuff fani ran paul howard 2020 whole lot say everything said inappropriate conduct coming back bite butt http co cscf0vlnrc',
#  'akhan4pakistan statedeptspox 100 every pakistani u vote realdonaldtrump one sort democrat conduct inquiry meddling pakistan pm removal involved rigging',
#  'former deputy pm therese coffey said con party conduct review islamophobia bbc morning minister often seem use islamophobia anti muslim interchangeably though badenoch clear preference http co 7vaefudxoq',
#  'nacab wearing seatbelt apprehension violent crime latter conduct occurred knowingly recorded imagine body cam',
#  'atensnut mattwallace888 demographic destiny future belongs able willing conduct massdeportations stop borderinvasion',
#  'jessseaco happy sober anniversary business life come go important conduct personal life high level',
#  'nypd officer begin run reason causing little scuffle officer soon begin conduct arrest despite nypd allowing sidewalk though given sidewalk across street protester find reasonable http co x9nyvnjgfh',
#  'gavinmyaz original question query law framed discussion employer conduct merit otherwise framing provision',
#  'abolish police use weaponry arm organised working class submit officer choose surrender peacefully forcible rigorous reeducation diverted socially useful profession conduct tribunal finally bring abusive officer account',
#  'nizmhani think warsaw jew able conduct military action nazi really good comparison',
#  'work digital accessibility tpgi ricky onsman created list upcoming tech event conference help stay informed read complete tech event calendar http co eqtqnidhmm accessibility digitalaccessibility a11y tech',
#  'update scoreboard cascade collegiate conference men wrestling championship feb 17 http co y5ixdg1u4h via 406mtsports',
#  'ahead much anticipated 2024 music amp drama education expo musicedexpo thursday friday hattie fisk pick exciting segment bustling conference programme http co dnxdyclmwo',
#  'dare parent teacher conference grade suck http co ogqn2hagf6',
#  'prem_thakker us reason unwra though credible incorrect unwra explained clearly ft eu press conference etc got proof fired immediately save reputation operation',
#  'gb51_50 cardn_al really older majority list oat wade dusty r 3 50 missing tourney bc he hardest conference chb',
#  'think nfl format probowl week chip would much value meaning make cash payment similar play let see league best conference remaining play',
#  'jalexa1218 another way putting cnn would much likely cover exclusive sit interview conducted anderson cooper random press conference nato bunch non cnn journalist ask question profit medium part capitalism',
#  'oceaneering participate investor conference j p morgan global high yield amp leveraged finance conference scotiabank energy amp power conference oii http co 3lvwzte1n7',
#  'nugsandskers15 fine care count use argument talking modern conference',
#  'camjpatrick wrong industry conference suck',
#  'biden administration sends cackling harris germany talk security conference want hear anything someone cackle time sure supposed believe security country good hand woman',
#  'kgwnews aaronmesh discount ant sharpe scoot ect fun young player watch hope best reach western conference final like dame cj failure cronin criticized managed team',
#  'idf spokesman rear adm daniel hagari announced press conference military found video bibas family gaza shortly abducted hamas october 7 http co z2lj8drt2a',
#  'guess stopped 37th black history invitational swim meet one d1 hbcu swim team huswimming amazing attend fresh conference win extremely proud team coach nic dcwave dcdpr http co g9hw1jb2um',
#  'gacademyleague put awesome experience frontier conference gatalentid thank coach competition proud represent stldevacademy teammate stlda_09ga topdrawersoccer thesoccerwire imyouthsoccer soccermomint http co g568hc1iva',
#  'cme training past weekend oklahoma city amp phoenix join one many conference location http co at56hvxuvg',
#  'thecadeera willjenjoyer realize 2 natties better 3 conference championship',
#  'h wrestling stephen decatur earns seven individual title en route winning bayside conference championship stardem',
#  'jsolomonreports news conference tomorrow 12 noon expected drop personal deficient 65 million dollar',
#  'spinnycore bad condition look good least distance',
#  'relieved new insurance decided pay austedo drug relieve tardive dyskinesia condition occurs taken antipsychotic antipsychotic year relate',
#  'jujupunter omo condition poor 9161538633 incase anybody want make join complete condition',
#  'gnozid cc2ventures parcl condition crypto friend care even thought try',
#  'radiogenoa sorry see mental condition sad man even want',
#  'wtb lf seventeen ph joshua seventeenth heaven kpopmerch shopee ld long dop budget 500 max onhand stbo ok good mint condition dm offer crdts owner pic http co cm3bqqqe6q',
#  'mehdirhasan pundit really need get move mostly like sitting brunch shocked fucking thing fascism fully take fuck would want recover',
#  'jujupunter omo condition hard ooo get 1k sef',
#  'justintrudeau tell people area northern ontario seriously ill deadly condition',
#  'eringreenbean condition mankind',
#  'bsports2193 johnrabe condition wouldnt really give shit thats yadis situation fo least whatever want theyll always find place fully commit work get time youre yadi',
#  'hell recommended teamyoutube trying watch video western athletic conference man send mr youtube http co o965bdz4o8',
#  'dennisattaway1 conwayvinny2 final four solo everyone accomplishment seems standard different auburn play win ncaa tournament alabama play conference achievement 2 top 5 overall seed team lost sweet 16 twice yikes',
#  'dschlopesisback vp munich conference news broke',
#  'jturner904 hater_radio lmao good conference went 4 6 v acc 1 2 v big12 like conference top heavy uf see top long time',
#  'leslieesc work conference dining alone right often love first felt awkward always sat bar felt le weird table cool might nice middle step hope great time',
#  '305ute pumpjack_joey utahbetter glasshalfute poverty conference invited colorado invited',
#  'hugosuperfreak brianroemmele u care emission nice way protect national car maker foreign competition',
#  'tatum missed conference final twice prevented embiid seeing first 3 time',
#  'labbeyondcities say nec need permanent seat twitter account might bring rule change next lp conference',
#  'monthly rate starting 55 per seat get enterprise level workspace fraction investment let center power success offer fully equipped conference room cafe http co 2t8wadsuww info sourceus io bpo bpospace sourceus http co r7fr16jbos',
#  '1liedetector georebekah elonmusk think overestimate determination half closeted degenerate last time looked one conference cheering gay black dude man dress looking across pond know nuance sys',
#  'tylersmith_isl pacer lost king two week ago 3 western conference type team pacer would able beat order compete nba final',
#  'jv 19 2 12 2 fall east lincoln 46 47 incredible season young guy conference champ two year row',
#  'hey pac12 destroy conference 1mm per year salary saving 2mm v former guy',
#  'swim win new record tonight nescacathletics championship tuftsswimdive sophomore quinci wheeler 50 breaststroke title time 28 47 second new school conference championship meet pool record set previous mark 28 51 time preliminary morning jumbopride gojumbos',
#  'al hamdulillāh conference underway shaykh amp ustadh kuttaabsalafy cannot attend tune via telegram http co rfvwtj0goc',
#  'cubosco jmb_cu16 troutiger opening day boy cane hired assistant fired staff young decent talent tournament bid maybe eers top 5 college prospect nationally weatherholt solid roster tough conference tournament bid clemson',
#  'anyone wanna recreate cotton ceiling workshop morgan page one seven people attendance terf complaining radfem 2013 conference london',
#  'mikebires putting conference would eliminate one school playoff putting quip section 1 survive advance least make playoff record headed headed match ups design knew',
#  'shame wpial football committee put aliquippa conference includes plum moon good grief',
#  'definitely going parent school meeting teacher etc husband somebody gone damn pta meeting parent teacher conference',
#  'comparing west conference final regular season star game wild disagree funny people trying compare two',
#  'wpial_blitz must keep absolutely stacking black hill conference 1a toughest conference 1a 15 year',
#  'conference advice care tbh',
#  'fccincinnati let post distract fact fcc blew 2 0 lead last 20 minute eastern conference final columbus crew',
#  'listening press conference morning seriously thank jewellloyd',
#  'd3vjavu isaacromig1 jayloncarrier felipe4prez briittanyyrosee big12conference felipe4prez stone berth big 12 conference plz',
#  'thankyou 2024 national conference sponsor california conservation corp foundation 2024 national conference march 19 21 visit http co c9suk15glf register learn findacorps jobsatcorps americanclimatecorps corpswork thecorpsnetwork http co hnz4bqgga4',
#  'illuminousone day conference learned paid team member leadership told leadership go day went let go said wanted something new knew timing sucked better time',
#  'rishisunak leodochertyuk wife widow alexei navalny speaking reporter munich conference vow revenge putin interesting invited munich beforehand amp speech ready planner knew coming death well advance',
#  'gaylersalama the_assr wendengibbs anoushehsayah gayle great meet hear amazing csf leak work thank wende organising fabulous conference',
#  'jwhittaltwn cool jaclyn try tune set reminder using link attending am tropical conference attending presenting fiona http co mkwh4saeko',
#  'albemarle corporation present bmo 33rd global metal mining amp critical mineral conference alb http co v55phnkdva',
#  'fading public fading cappers give virginia 3 5 75 unit give virgina ml 25 unit virginia 20 6 11 4 conference beat virgina tech 14 11 6 8 conference gamblingx http co j4gih4u7gi',
#  'kyle shanahan hold press conference tomorrow address state late game deficit chief',
#  'eringreenbean condition mankind',
#  'justintrudeau tell people area northern ontario seriously ill deadly condition',
#  'frankconniff novel deeply aggravating slog designed stored bookshelf pristine condition people cocktail party appreciate depth sophistication',
#  'ustadh_dragoman jqaforpresident yes irreducible one part ordinary magisterium church analysis creation account precisely answer question posed claim merely prelapsarian condition human nature',
#  'due hectic schedule condition decide put account upchar dm miss ya moot http co hmwceaysor',
#  'nyamber_ notdreamland siirdada recovery def main weakness every character main win condition referring frame 1 nades people actually true combo useful year ago def help stage game exploitive',
#  'jackryan212 current condition carrier want back ccp please help need meme haha http co k0nghwgsjh',
#  'jujupunter bos know say next condition giveaway go need 3k get',
#  'wts lfb ph fujifilm instax mini 11 pastel green 3 5k box good condition onhand free clear case amp lace rf upgrade mini 12 dm reply claim send photo thru dm camera film polaroid instax mini 11',
#  'second part treat moral amp religious condition slave amp free black blaming circumstance lack virtue http co 1e467mp9fd',
#  'jonnie1waffles life_minutiae bladerunnerjul1 amayadeakins swipewright hey jonnie1waffles curious take scientific study gender cultist drs reference proof gd transgerism real condition say cant define gender identity heck study draw conclusion pic rel http co eewkt25kmn',
#  'today skip live streaming due body condition bad coughing lot bit hard continue talking singing right see next week nice weekend',
#  'poch make resoanbly clear start mgr criterion selecting team game day match training performance training attendance punctuality tactically ready physical mental condition attitude opponent obligation forced',
#  'leper abercuawg writes god undo expression despair condition declaration ultimate hope http co zoeyfocejb',
#  'kevin knuth favourite guest speaker sol conference chriskmellon best laptop decor ufotwitter ufo ufo ufosightings uaptwitter http co yy5beeonkl',
#  'alexandriavagov congratulation advance inventing 1 8 conference per week drawing roughly 1 800 visitor every single week http co ajyubxfhnz',
#  'congrats igb16urisedues mackenzie feeney named paac conference honorable mention great job mack igb_hoops',
#  'press conference dixon said watched hearing mayor head would rolling dixon went say police commissioner missing action testify hearing referred monse director clueless',
#  'bowtiedhitman honestly probably one better press conference recent memory',
#  'akams_ tucker said uae conference every leader kill people others',
#  'tasting climate change conference 2024 key takeaway http co 90lnhiqfpm',
#  'science conference one big flex competition',
#  'download fai 2024 conference app view every panel workshop summit showcase save event build schedule plan trip everything need next week fai 2024 app http co x27djvwmew also go listen alice hasen pictured http co hlmcksycuc',
#  'royal college gps forced u turn cancelling gender critical doctor conference http co fl4tjra295',
#  'pro palestine activist set protest scottish labour party conference http co r3ruxbjfve',
#  'watch florida win total set vega 5 5 thought ryan nielsen press conference thought plus new ea college football video game coming soon dylan denmark graham marsh discus denmark marsh http co uyzrhbjory',
#  'lafayette high school basketball team hosting midland empire conference foe st pius evening st joseph girl game first highlight tonight kq2sports lhsirish irishactivities http co gg0uukztgk',
#  'world food programme wfp used munich security conference reveal new building innovation accelerator office city follow coverage conference subscribing devex newswire http co ea83wufrce wfp http co 2opae0umac',
#  'ongdevlab circular dependency also outofboundsexception people answer string split regex size gt 2 yet condition lt 3',
#  'yay_its_james look like sepsis condition caused many infection could blister sore throat chest infection say hospital equipped diagnose sepsis',
#  'kimmythebrand bwoyatingz realshellyannfp believe need space protect dearly sad truth assimilated foreignitis without even knowing show option condition consequence living medium food consume foreign j infrastructure compete',
#  'hipsterunionrep apart condition spew hatred seek undermine value country think missed bit',
#  'choose like tadashi satomi emotionally sensitive plot complex character p1 p2 dd like shogo isogai thoughtfully composed story demon human condition sj nocturne helmed cozy okada time kazuma kaneko http co rcrcib9oz6',
#  'fisayosoyombo fijnigeria ruffydfire fisayosoyomb davidhundeyin become disgrace profession matter u lost way journalist never become news condition committed libel ibd dende accountability fact matter',
#  'think ever claim something unless like proof insanely strong feeling like hate people claim depression like claim condition make feel like discrediting people actually suffer',
#  'treywtff lying gotta ur worst mental condition',
#  'one join anyone care color long want change miserable condition exists earth malcolm x http co cw1lwgwknz',
#  'sarahlicity fightful deonnapurrazzo depends job place anti poaching rule sign condition employment',
#  'fight infection forever bee propolis shop http co ztt6vnzj35 disclaimer statement regarding dietary supplement evaluated fda intended diagnose treat cure prevent disease health condition health http co j4cyvj9amn',
#  'vintage hardback copy constructing sexual crucible integration sexual marital therapy great condition great read anyone interested marital counseling http co 21ugwpzdac etsy counseling psychology therapy sexualintimacy relationship',
#  'queenie4rmnola broke family took away love one another gave u image god look like u dr king said also wonder condition',
#  'decatur wrestling bayside conference team champion sdhs_sports sdhsseahawks',
#  'yes think potus could substantially worse mexico egypt press conference bibi mccarthy think sharp mind potus show',
#  'g league first team conference jordan mesa 26 3 point 4 7 rebound 5 3 assist http co d9a1lolisb',
#  'lftcf _mplsmike_ governor representing state surge crime murder hand multiple reason multiple people press conference police union',
#  'mentalist51 rtenews teresamannion pentagon admitted running 46 biolabs vp kamala harris confirmed press conference like insaid think dod biolabs offshore handling dangerous pathogen proof existence confirmed admission http co flye6efqfm',
#  'congratulation dead conference preside',
#  'basas delighted announce 2024 annual conference take place 9 11 september king college london',
#  'rishisunak leodochertyuk planned false flag operation brit lost empire army fleet still remain world class let u note death came day opening munich security conference many leader collective west gathering',
#  'jjmetzfau think 4 1 2 win conference tournament still safe lock',
#  'basketballniice cfcshifty legionhoops nugget good deep team 2 year bruh 1 2 made wcf performed every single series level expected window chip 2 season stacked conference ever got close 1 underachieving',
#  'nicobam15 hossbrewer amp jweatherley21 thought season opener full press conference head lr trojan youtube page http co bugwhwj4qt littlerocksteam http co sgiwylsxwt',
#  'big12burnerku want pitt conference much anyone tbh think could market virginia tech wvu black diamond trophy better market backyard brawl plus wvu pitt likely play non conference year',
#  'tier 1 nfl jr 30ish biggest brand regardless current conference spun university wall street saudi etc owned professional team tier 2 cfb 75 100ish college football team afford pay house nil tier basically dii',
#  'matthaeus0707 ericruiz917914 sharpcutco rkuhn5167 2308woody evidence evidence presented big ten commissioner caved due pressure conference coach witch hunt',
#  'mark calendar 2024 retail supply chain conference dallas texas rxo february 25 28 connect booth 1003 see rilalink http co 65dvi1etkd http co iexhh6oz1k',
#  'publicaddress haha almost better announced major conference working transform rug policy foundation yes missed every important',
#  'jacksonhinklle 1 interview putin 2 interview xi 3 sit ayatollah chamenei 4 conference world peace',
#  'join lwvmpls minneapolis community connection conference saturday february 17th 9am 4pm minneapolis convention center stop booth helpful voting information approach mn presidential primary march 5th including make plan vote card http co pvwjdwg7ua',
#  'jax_mbb key another season making conference tournament',
#  'jb_snkrs1 matsheltoneide fortunately think mason probably middle pack conference ability pay may big divide public university v private university',
#  'jerryrmitchell1 pierrepoilievre yet problem chairman justinsane spending 61 000 two day conference surrounding poverty 75 000 day security',
#  'islander gear another home conference weekend http co ih42rrxdhl',
#  'fund congress account frozen dept wrong liable pay press conference go supreme court right remember fighting tooth nail ram temple sc http co lavrgkox6p',
#  'fabrizioromano good discipline player stop calling everyday conference day need respect well',
#  'tomorrow game day make sure tune peach belt conference network watch first game season http co vlnepxde6t',
#  'blackgoldfanpod top tier arena conference least yall safe mizzurah streetz',
#  'rncresearch biden came camera display total control mental faculty special called press conference temper failed badly',
#  'perennial title contender 1971 1992 made least divisional round 13 time period made conference championship game 6 time made super bowl 5 time 3 time want say goal post dynasty 3 super bowl win five year qualify win take place 83 88 92 humble opinion dynasty team player show dominance extended period time played washington 70 early 90 going battle',
#  'dilligaf963 ada_peepos say luck say mental condition fren either way stopping http co 9agvf0w0tx',
#  'sameihuda quest free everyone label going turn inside long challenge concept neurodiversity invalidating suggest dx mental illlness growing awareness condition equal psychiatric takeover',
#  'rest well scoups mind brain understand serious condition',
#  'fareed zakaria writes today http co yn38uj3utk visiting oxford based surgeon nick maynard described condition hospital gaza one partially functioning saw mainly lot child coming appalling injury many knew going die give pain relief often morphine nowhere die dignity often literally left lying floor corner emergency department die american policy gaza war appears hapless ineffective immoral image u official wringing hand civilian casualty providing ever weapon grotesque',
#  'taichoumilkttv win condition mmr',
#  'polnareff trust hope recognize trish seems hard time understanding make feel worse condition',
#  'theatlantic grahamdavida mitch mcconnell ever provide resistance set back let shit happen acted like stuff big deal much blame condition government cheeto satan',
#  'favorite shoujo queen quality raeliana ended duke mansion happy marriage condition called love http co 96y6kliht3',
#  'severe mental illness gender dysphoria condition meet standard recruitment retention next commander chief immediately diagnosis medically separated retired eligible',
#  'kat_missouri madrid_mike assuming security service preventing taking sample condition even allowing funeral certainly independent autopsy',
#  'tulpapilled opinion alive course somehow alive care thing condition future way get rid give shit',
#  'podpatriot severe mental illness gender dysphoria condition meet standard recruitment retention next commander chief immediately diagnosis medically separated retired eligible',
#  'nutmeg984 angryblacklady idk cutco knife guessing already planning mew countertop condition sink',
#  'birmingham nfu conference good get know fellow farmer region dinner catch friend looking forward conference starting tomorrow nfu24',
#  'presented conference looking help folk community become better presenter volunteer southeast dreamin speaker mentor today sed24 http co u5fvioz5c1',
#  'leannecpowner thanks much sound advice leanne present planned conference paper describing whole research project future monograph covering multiple aspect translation amp various theory ambitious 20 minute',
#  'yeaderrr comparing western conference final damn star game nasty work',
#  'honestly come 400 take 0 84 200 pr conference meet answer katv157 doanetf gpactf http co znzwt6u5uo',
#  'drfrancois1 thanks contribution mizzou sorry see go best wish new role enjoy press conference formal reception always get back work best',
#  'tried way attending econ conference experiment interestingly road lead rome end sit session fascinate u communicate research scholar u like hang amp party old amp new friend ur presentation',
#  'parent child died high school bathroom showing parent teacher conference like http co wfajqdmhj1',
#  'pbbm lead pnp command conference http co wnsqhvfgwd via malaya business insight president ferdinand r marcos jr thursday presided pnp command conference held camp crame quezon city malayabusinessinsight malayaonline http co a89kpiiqik',
#  'understand wpial put aliquippa moon conference school virtual crosstown rival',
#  'illboardroom get sentiment loser mentality serious team hunting conference title take care penn state make excuse ahead time win hang banner',
#  'rawilke24 cyclonelarry69 jump ship iowa state fan suck never win 10 game conference title big sport',
#  'deportetotalusa messi play playing 30 regular league game conference plus la team play playoff etc',
#  'time villanova v georgetown washington dc listen free local 89 1 fm dial http co xtcp8owngl free radiofx app novambb look second consecutive victory improve 7 7 conference play',
#  'malcolm_flex48 call conference coffee academic understand',
#  'working paper regional conference blend two discipline teetering yeah make sense goodness making sense see go',
#  'stromio1 conference straight as',
#  'baltimore mayoral campaign incumbent brandon scott democratic challenger sheila dixon trading barb follows dixon friday press conference state attorney office citation docket low level non violent crime quick thread wbalradio',
#  'let review month trump said judge clerk corrupt doxed clerk said schumer girlfriend motioned mistrial saying clerk telling judge held daily press conference criticizing judge wtf expect',
#  'scott keft youcancountonmb detailing scope australian competition consumer act kick second day queensland conference http co befpyahbgy',
#  'russia navalny officially dead anniversary key putin speech navalny wife speak conference former u ambassador russia michael mcfaul putin killed navalny consequence csiemaszko http co zixfb2e6uo',
#  'byu last year bottom half conference much worse pac12 seem alright big12',
#  'shiffa_zy mother fake press conference http co 09op3ogktf',
#  'found staff conference year vega end day birthday oh fucking wrap',
#  'tatianyc27 yulia navalnaya conveniently germany munich security conference brings together national leader foreign minister expert husband navalny sudden death occurs part cia diabolical plan rally west putin amp russia',
#  'attended digraaustralia conference week presenting part research videogame ontology analysis myth hunting grandtheftauto http co aubnn52tci',
#  'bdfitl cambattle100 coachdanmullen cfbrep played conference championship team stroud throw single pas 2020',
#  'na0sglass anniegirl1138 beyerstein kiddle maej43 luciecatnip doloresquintana chessa222k uriebay understand oral painkiller still go otc med pain patch effective depending condition treated course',
#  'assume politician campaign lawyer might found way monitoring thread lawyer realize everything read online true took information given campaign worker condition privacy research experience campains decided excess monies distributed million funneled reelection campaign incumbent challenger point section fec law address',
#  'beckybela calirn619 owenshroyer1776 work leftist simpleton collect ten thousand free money amp benefit one condition must vote biden november election mean keep regurgitating mainstream narrative',
#  'build beauty sucking helium human condition نمشؾ h20 ٺون 888n',
#  'defenceaust people pictured endure horrific bodily trauma total defeat w w 3 possible victory condition',
#  'ncc give condition reconnection disconnected gsm subscriber http co btanhjb9fu',
#  'tbgtnt yes friend best doctor said position discharged month condition still critical due cardiac arrest know stay end thank much everything dear great weekend',
#  'paying collector price looking actually use almost condition',
#  'dougs_cars amazing condition wow',
#  'primarily trustee sale buyer get inspect anything usually make guess interior condition exterior condition every get one exterior belies interior rehab budget order magnitude',
#  'explaining need deep condition brush hair exactly 2 day big event else look weird',
#  'dadrockenjoyer sure im insane believing last 11 year part workforce ive slowly realizing getting customer v getting customer actually primary succeed v fail condition lot business ive worked lol',
#  'something wrong find check ethereum nft token holding zealy_io quest saw condition polygon supported use api quest develop app existing micro app let know thought would like see come life',
#  'cripwriter fodderfigure parent even evaluated 12 camhs lost paperwork 18 cat hell chance even going able speak gp people reception listen come condition prescription',
#  'leonardotozzi1 indeed task contrast distribution leptokurtic second hump likely visual region resampling top condition gt implicit baseline contrast dist would atypical sure',
#  'genericjes censored4sure lot condition living standard improved health introduce dummy drug thank instead real reason improved hygiene standard called placebo effect http co rwwvlfwvk5',
#  'nataliejaymodel mrdarvill also kept record achievement still good condition look like twenty eight thirty eight',
#  'new york g letitia james speaks press conference following ruling former u president donald trump ordering pay 354 9 million barring business new york state three year nyc feb 16 2024 reuters david dee delgado http co whrpy93hdo',
#  'oregon county well represented 2024 nacotweets legislative conference held feb 10 13 washington c conference highlight included policy session critical issue advocacy capitol hill address president biden meeting ronwyden http co hcjvcihbjj',
#  'kerrigan myers conference champion pentathlon madyson ray gpac 4th place finish new pr score 2942 3rd time midland history shyanne pipkin finished 13th score 2196 http co 95uxzsdzx6',
#  'pumpjack_joey utahbetter bornagainbeard glasshalfute yeah stuck poverty conference',
#  'dpa_intl iranian dissident protest outside munich security conference maryam_rajavi http co ybfgeyzc3l',
#  'fbcoachlarson 6 1 260lbs iol c 3 5 gpa 1st year var starter c 2027 wisconsin state conference http co wc8ta7n4nj',
#  'general conference weekend',
#  'northern timeout central dauphin lead 42 13 mid penn conference championship 1 53 go',
#  'foreignfeline tried make press conference',
#  'colbyfootbalfan espnlunardi get rewarded playing mid major conference make sense time fraudzaga bc play 3 good team year',
#  'man light east conference ability talent scheme amp going counter insanely absurd statement might well made one mj agenda driven troll app',
#  'pawankhera point illegal pay perfectly alright question press conference go supreme court guy famous going sc everything remember fought ram temple court',
#  'repeteindc trendyhoopstars accwbb conference ranking joke year seem anti sec pro acc pac',
#  'rv30b justinesports potential football lost hc left soon became feasible basketball move needle today landscape conference solidly outside power structure little hope getting',
#  'illinois men basketball team went ranked 14 last week ranked 12 week winning 2 game 19 6 overall 10 4 conference six game go believe bad illini collegebasketball',
#  'jayjayallday31 zach_seyko team cobbled together three remaining player done great job keeping team respectable possibly best coaching job conference collins',
#  'd3vjavu isaacromig1 jayloncarrier felipe4prez big12conference feel like sibling big 12 conference fitting',
#  'kbender4133 psu_fb_thoughts on3sports andy_staples conference fine 2 school texas tennessee alabama mississippi worried market saturation add another florida school',
#  'rgryan777 rule breaker necessity take care health first mean running country going conference selling book try limit leaving office also formula writer read unpredictable',
#  'whoop whoop 2nd bitcoincash conference happening wait see',
#  'going conference san diego early april used excuse stay extra night go lakers game floor level reasonably priced april 7 praying lebron healthy lakers need game positioning play',
#  'sadeeknextwave loss divisional conference championship',
#  'preparing talk conference gathering preaching back old faithful still much gold http co tmtxi7rjex',
#  'abstract submission welcome scottish rcem conference 2024 vp_scot_rcem',
#  'mascott04 seeing anything yet btw gonna two mega conference sec big 10 one end gonna shot natty',
#  'japanese government support continuation war protest event held tokyo coincide japanese ukrainian reconstruction conference organizer opponent financial assistance ukraine japan',
#  'jalexa1218 simple fact done fewest press conference since reagan need respond higher visibility thing interview etc taking minor league question union shop visit campaign trial tough guy',
#  'trulytexan74167 apostle come stake conference elder bendar said need start revolution go back calling u change image taking sunday school ward stake conference setting',
#  'going die hill whoopee hit portal power conference work aforementioned boum read tweet never said reason golding struggle good luck hope utep get new coach sooner later',
#  'rosssymons ready purchase reduce fkin price 3000 inr fix bug think game current condition deserves much money',
#  'still available 1962 topps baseball 324 joe mcclain good condition 2 37 shipped ebay ebaydeals buyitnow topps baseball mlb vintage joemcclain washington baseballcards tradingcards thehobby http co mwbbwmtjli',
#  'infantry_bucky trying break colt condition riding first think',
#  'vidooch agreed sad condition soul mind',
#  'jamesbooth100 sassykinda9471 artstop radiogenoa hmmmm usually quran stay good condition rarely get damaged usually get replaced however case page get damaged piond fixing people usually give nearest mosque recycling',
#  'mareesolaris guy must stirring water looking laugh accept sincere condolence severe mental condition',
#  'collinrugg creature gave birth child cannot described mother forced live rest miserable life house condition girl found look well fed',
#  'bet symptom enlarged prostate make frequent trip bathroom every night recommendation alleviate condition',
#  'still available 1988 leaf baseball 32 nelson liriano rookie card excellent near mint condition 2 17 shipped ebay ebayseller topps tiffany baseball mlb nelsonliriano bluejay rookie rookiecard rc ratedrookie baseballcards thehobby http co 9poewm5w6g',
#  'cardpurchaser color big vintage coincides condition',
#  'johnjharwood choose guy walk shake hand vigor instead demented old man shuffle walk claw hand condition sign extreme old age',
#  'mint condition kind man would 1996 http co 7wssrjx51w',
#  'breakingx_news agreed mass medium used prep public also condition reaction',
#  'canada ready send troop ukraine one condition http co qdnoxeif6b',
#  'grown love washing hair sm washed yesterday want wash tomorrow stare beautiful curl deep condition',
#  'simpletruthnd boron interacts phospholipid tracking back morning discussion tg chat sure mean boron role played key part neurological condition decade learned http co 1degqjxbyd',
#  'thrillinoise iu fan hate acknowledging purdue super bowl team conference three year row one ever thought illinois super bowl',
#  'back another weekend columbus ohio bowling conference event 5 saturday columbus square bowling palace columbus oh raiderup raiderfamily http co cctaflj3uz',
#  'biotechnology high agenda munich security conference hill http co nt4vpobc8w',
#  'ourshallowstate trump pumping imaginary accordion hard press conference thought going break',
#  'amazing end catholic school week thanks joining u cisva2 catholic educator conference learning opportunity formation catholic educator st mark college ubc archbishop scholarship http co oqglbg735d cec2024 http co tn2nyutssn',
#  'christalthegr8 bad watch press conference yesterday',
#  'every western conference team could conceivably lose 1st round 8 current top 10 team could make final http co p8u6nsybzn',
#  'survive advance next wednesday feb 21 free admission delgado cc x baton rouge win advance conference championship game trying make history need support city http co kgebndmyd2',
#  'hi_fizzi okay second conference room totally calling snow themed princess party inviting 2 friend kek',
#  'gbaby1354 ffbuckcle first year qb physical conference need time adjust',
#  'thatbroncosfan_ defenddc99 mauler division championship conference get call back lmao',
#  'rollcrimsonroll knew division gone heard might 9 conference game next year tho',
#  'believe trump said urgent press conference n http co rxjniilzov via youtube',
#  'freihetzsender marc_kebo weird show conference supposed even wearing makeup cheeky post pathetic',
#  'going lie sec adding oklahoma mainly texas allowing boy play top dog conference first year going magical matchup next season texas georgia schedule crazy',
#  '7veritas4 ny ag said 463m press conference',
#  'stunning men heavy carnelian 9ct gold ring size v 8 9 gram excellent condition http co bvww006kfx',
#  'smile9201 like much mistress feel condition might go worse find',
#  'house hunting focus layout location condition changeable detail like flooring paint element future home temporary outfit teamomerz soldbyomer soldbyzunairah yourrealtorzunairah yourrealtoromer kitchenerrealestate waterloo http co hyacloum8q',
#  'sherylcrow going releasing unavoidable medical condition sherylcrowisabully',
#  'stunning piece perisan tabriz lovely colour best condition flooring 4 00 2 93 cm http co qiovvn2veh',
#  'ausss2n looking one reposted ur happy fun made condition made ppl explain though okay fun guess',
#  'annoyed today fully realizing part decision dismiss personal injury claim go like allergic condition magically resolve moving proven property caused believe real',
#  '77_steeze working hard condition u lower expectation handoff ai seamless',
#  '_fullkitwankers forgot mention absolutely great condition pull material anything',
#  'drmcthickens djp8401 mrandyngo 3 physical condition think psychological condition',
#  'beamailuc jayzeae ony one health condition rest mental condition unfortunately mental condition treated cutting schlong sewing flesh interesting pride considered virtue applied vice normally',
#  'harlemj11 nemanjayvr iirc church sold land condition citi would build new building congregation base tower',
#  'bunbunpillow contagious disease hereditary disease rare condition happens sometimes viral kind infection girl woman likely develop itp rather men boy yes one people itp',
#  'frankconniff frank unless book solves millennium long question human condition wasting time',
#  'understand intent behind sealing liquid shower product anyone actually remember remove seal beforehand accepting humiliation part human condition',
#  'bentables thread pengbudols price per item indicated per post 50 nrdp 7 day dop w 3 day grace period mine basis dm mean deletion reply item good condition amp onhand disclose dent pc claimers sensitive',
#  'great day attachment amp trauma network creating trauma sensitive school conference endseclusion http co tunsvbv9fc',
#  'pre season ranked 9 10 conference top 6 team make aye want say 24hr countdown til first round tip',
#  'horsemenpod figure coming point look conference make rule force issue nd play schedule 12 mid major b1g big 12 fine sec',
#  'famogang365 w road bama wednesday night would boost top 25 ranking lot steal w win home game rest season good place finish 4th better conference earning u double bye conference tournament',
#  'big man recording taylor v catterall press conference hello kitty ipad http co fh76ygu824',
#  'conference champion get small prize national champion get cool prize',
#  'big12burnerku miami pitt situation campus stadium people city care way pro sport fringe conference championship caliber team every year ask 2 people likely turn miami',
#  'illuminousone rest team got go wanted attend go conference paid put pto said think fair change personal goal early bday plan',
#  'big 10 3rd best team 9 loss second best conference glad see everyone hyping mwc though',
#  'utep head coach joe golding conference outlook thought backcourt play 600espnelpaso http co agtcwji8ur',
#  'therego_deee xhonkikong sixbillz woeeleek yea dumbass realized wrong either way cause tryna say conference title',
#  'gameday tonight start week mizzou d1 conference excited another great week match rocket league team engine roaring ready start thing see field 7 00 pm mizzouesports nacestarleague http co ylbfd8krqa',
#  'gawbaey hoboj_ star top 4 team conference',
#  'event gy regional energy chamber launched guyana energy conference newsroomgy http co uzoalvbqws',
#  '2024 02 07 press conference sheriff richard k jones butler coun http co h38kqifwxw via youtube',
# ...
#  'jacquieteo1 joelklatt example take cam newton player team ever play game nfl mediocre defense still greatest conference football natty elite nfl good great',
#  'stevenlorettat1 vol_hoops would better honestly kentucky blue blood cakewalking way conference shown much interest sport last five ten year honest',
#  'press conference tomorrow tuesday 9am address violent assault teacher parent inside classroom front student lincoln m syracuse briefing closed public assume mean teacher amp union sostayawaypeople orrsvp http co abgiwgn4lq',
#  'big 12 want pitt miami backyard brawl go pitt miami like said network pick school conference',
#  'chrisland saga daughter medical condition whitney mother http co 0yt7fcsiel',
#  'assessing house roof condition something every homeowner know retips http co jggeaf3wx2',
#  'assessing house roof condition something every homeowner know retips http co rhqd6tewxo',
#  'trans_catboy yeah remember back truscum shit culture deeply anti self dx whether neurodivergence mental health condition gender dysphoria remember someone saying diy trender',
#  'sump pump installation know property owner got lot plate last thing need flooded basement worried condition sump pump call rooter man offer new sump pump installation http co ccgjxo4xut http co zpoihirv82',
#  'currently hyperaware human condition make wanna throw',
#  'well concerning somehow surprising light rap venture hamstring condition',
#  'supply nuclear weapon palestine use israel case war let destroy enemy humanity islam put condition sunni gaza convert islam face defeat jew give one choice lose support',
#  'jiminspogostick joondimpl_ acl recovery 6 9 month whatever know many nfl player go back playing football year 5 month even fewer still 2 stepping gda took test 5 month early knowing would better condition near birthday digress idc',
#  'thisweekatjustice justice department implemented groundbreaking executive order addressing national security risk data security family dollar store llc pleaded guilty holding consumer product insanitary condition http co dnxi9zfnwe',
#  'stxrzgives tentacionfn current condition many acc got suspend maybe support team need longer time work hope ur acc got back',
#  'watch new york attorney general letitia james news conference http co cveemesoa8',
#  'joehealyd1 ukbaseball usc picked win conference take game 1 pumped get rolling',
#  'view afternoon room innofthemtgods ruidoso nm sensational trlp leadership conference elpasorealtor http co lfqalzlgjd',
#  'rumroomt thing remember various reason world saw doctor giving press conference among dead amp erupt',
#  'join rcmadocs amp iefmc 1st annual ai healthcare conference 4 26 day innovation insight amp networking miss opportunity learn future healthcare information visit http co reayr70auk aihealthcareconference http co l0byentygv',
#  'slowly surely gettin back motivation good work machine learning back mindset believed mua self publish conference someone ml',
#  'coachmecoach23 http co 7jzfnnx0qe gpa 3 4 rb slot kr 940 rushing yard 1 499 purpose yard 13 touchdown ncaa id 2009927197 spring graduate 2024 10 game highlight conference rb purpose offensive player year state purpose yard',
#  'iujeff sethtow yeah first thought lady game well one conference national implication probably highest rated watched game four even peacock would even loved home red v yellow white stadium',
#  'dr_meming finishing conference http co jcvxfbotjj',
#  'cfinklea coastalbaseball antonacci springfield played conference jdub juco insane player',
#  'photo op conference private amp away actual people optic got',
#  'rosemarycard vein influencer conference boncom know kind scratch back somehow type deal',
#  'japan commit long term support ukraine conference tokyo http co xhjhxikfpp',
#  'wogpogreal february 16 cpac chris dacey derek noonan parliamentary press conference full http co yxtu0arinp',
#  'ju_khatib exact press conference clarified exactly meant somehow people like want ignore take said context http co 23txjsuwyb',
#  'simonateba ginning excuse giving ukraine billion hard earned tax dollar wish press conference behalf united state brave service people killed past three year',
#  'anarchrist5 derekporter_ one greatest fictional representation human condition possibly greatest',
#  'aint even voting system george washington wanted condition become inaugural president voting system led strictly people separated combatant party dy immediately scrap system',
#  'hate condition face still hey gatta wear',
#  'cuptwost ah gonna cry use wheelchair heart condition really nailed feeling wanting burden loved one feeling isolated',
#  'wif new phase first phase 1 seemed expensive feel cheap thus reset market price condition psychology participant',
#  'proudliberalz long making purchase u ya go good mint condition matching serial number v12 neighborhood 100k sweet thanks http co rimnxbq5af',
#  'one condition imagine manager needing subordinate master needing slave condition would instrument could work word command intelligent anticipation like statue daedalus tripod made hephaestus homer relates motion entered conclave god olympus shuttle weave plectrum harp playing aristotle',
#  'onebaddude_ catturd2 stop pretending one side fact part human condition human seek information fit world view reject information regardless factuality enlightened folk aware human weakness compensate accordingly',
#  'slabrador darrengrimes_ national condition prime minister must least 6 foot',
#  'drive behind taking open imaginative collaborative storytelling schema entire strength open frame lack precise ruling codifying mundane known mapped boring game space win condition gear grind next',
#  'calabria skysport milan mixed performance agree high low think also depends lot personal condition example game long run becomes difficult maintain high performance team better great team data hand bringing big point talk inter incredible championship congratulate great job',
#  'fufla1978 lucia_sibanyoni bbmzansi mean two color tone fake beauty jelouse zee wig make make sense despite skin condition still look people wonder god gave skin jeezzzz',
#  'long term condition review afternoon blood pressure little high got told relax thought happy thing like favourite redhead favourite redhead chris_meloni blood pressure went instead http co ojuldshkmq',
#  'frog supporter believe fatou commit suicide larissa left group know well fatou condition worsens korean member leave http co 8r1wlhcwro',
#  'outrageous leaving aside condition nh trust chaired next billingham wrote puff piece peel assessment kent police seven year running including much period force failed stop called couzens monster knew complicity http co uh1uxjjwmr',
#  '_gatafan34 jmilley22 steveitalltome nole_atl know fsu passionate fanbase lol however proven year winning conference acc longer mean anything rather competition respected',
#  'liveonlocation fashionably late union pine first round sandhills athletic conference tournament hoke county visiting viking 32 11 lead late 2q http co jmtqzeln2v',
#  'week roatan honduras longevity biotech conference http co cybppchyeo feb 23 25 2024 join u 200 longevity enthusiast exploring groundbreaking advancement biotechnology sign http co oyvqyh5lu8 http co osjta5kbih',
#  'jjmetzfau conference get 1 slot long owl longer top 25 winning aac conference tournament chance large almost impossible none team ranking',
#  'please conference one organic space interact still academia',
#  'minute feb rba meeting tare released morning expect lot given governor gave press conference meeting somp forecast released gov bullock appeared parliament last week may talk u guess',
#  'find ai skill need 2024 odsc east leading ai training conference featuring hand instruction everything mlops generative ai register http co iseyz5dumx http co nhg1ilbymr',
#  'blerds black magic cast spell indie sci fi fantasy conference spark back 3rd time virtuouscon week 23 25 feb vendor visit virtual booth 12pm 5pm est free book outline turn idea instant book see convirtuous http co brqo6gpq1o',
#  'kwest_okc luther4heisman mizzou made sec championship game second year conference made next season definition struggling know tell',
#  'started named southern conference preseason player year accolade honor pouring western carolina university vonterius woolbright senior men basketball team read http co shogyeexhh',
#  '_gatafan34 jmilley22 steveitalltome nole_atl man need break one pumping chest three losing season conference said moment cool bang head sec better 10 year may suck go cycle',
#  'ipopstats net data never going accurately reflect byu beat bad team conference 47 57 43 28 29 41 16 32 42 26 insane sole reason outlier net ranking opinion nothing good team',
#  'attending public wealth management conference put together mofi later today transcorp hilton',
#  'great view waxwing norwich research park today visit please park site anpr enforced parking restriction 100 fine park old watton road walk short distance john innes conference centre http co nqcb5xuksy',
#  'come learn kade sharp supporting autistic trans youth 3 50 pm 4 50 pm something identity y dsi international virtual conference friday may 31st 8 5 pm pdt dsi autismtransyouth autismawareness neurodiversity lgbtqia autism http co lk2p0ybvjw',
#  'thanks everyone came last weekend mid atlantic rowe regional conference shout host alpha pi delta nc state http co 4lsfevkioq',
#  'searching last time az conference champ found pac 12 website list last national champ pac 12 team look 2008 get cool like byu 1 national title naw personally count could care le know ended year number 1 year national title matter new playoff format b popularity contest winner national title given one',
#  'cfc_jace danieiscouting chelsea even conference league',
#  'qatar pm meet israeli president munich security conference u treasury add houthis sdn list terror designation go effect biden administration official say u want unrwa work sustained uk cameron say two state solution subject israeli veto follow update http co un2fmditop',
#  'lavrov take part euromaidan ukraine lost decade conference key point http co 6iyd92fpg5 odysee via odyseeteam',
#  'press conference tehreek e insaf rigging white paper released candidate affected rigging put respective constituency form 45s rigging video evidence global medium forms45 http co z4nhncot5n http co hxodeqtdcf',
#  'simonateba amazing biden get upper hand republican probably era electoral advantage clear forceful press conference alexei navalny death',
#  'collegehoopsguy bracketologist3 grahamdoeren committee bend rule first four team conference top four line different region conference four team top 16 overall',
#  'aab_fi awale11 watch birhanu jula conference play dumb',
#  'calling virginia area east coast educator check vmsa annual conference march 8 jmu http co vs3mibqtnx jacked vmsa conference keynote speaker opportunity meet learn many inspiring educator http co mg2enuxonw',
#  'jack1147892 gloverscast simonthyer looking business account total last year 600k profit club show profit maybe hold conference reality club limited revenue angle',
#  'pac 12 parting way commissioner george kliavkoff oversaw demise powerful conference league wave realignment last year http co vqltfz5kxi',
#  'whitehouse excellent well controlled press conference biden make sure every reporter get chance',
#  'bakerbee1 vapinsquirrel algore09algor simonchapman6 iirc 7 8yrs ago 1 month european jolly supposedly odd conference speech whatever constantly counting member public vaping guy totally consumed goodness know decided focus topic',
#  'blog spotlight 5 conference room display trend boost engagement hint go big go home http co pgxrjkdtf6 samsungbizusa digitalsignage videowalls immersivecollaboration userexperience employeeengagement avtweeps',
#  'le 30 minute away billikens v vcu atlantic 10 conference action chaifetz http co r2uwar1qo2',
#  'raw press conference houston area amber alert lake livingston dam loc http co 2pfr6khe1x aurdiicunningham amberalert missing missingperson',
#  'excelerate energy participate upcoming investor conference ee http co qzaw8qno9y',
#  'sonicsmash259 combination chromosome yes much exactly objectively wrong yes yet blue eye condition still list eye color lost',
#  'potassiumyz getting moved da subhuman section cuz adopted know condition birth http co vudqdpwidh',
#  'annemar44470568 downstairs function ok condition upstairs used residence used function leak poor condition',
#  'fuck_xdotcom cuban non capitalism created condition people penalized growing food lack food party member never go hungry neither shortage store foreign tourist blockade fault',
#  'ninaturner know way win anyways need creating something new right sitting around brunch waiting fascism even fully arrive',
#  'paperback edition delicate condition danielle valentine including brand new bonus material released april 2 http co rmcznft1te',
#  'context au ethan survives re8 eveline able regenerate heart mold mold weakened heart poor condition 2 2 http co nibyjinrbm',
#  'clear hint bcci play domestic cricket else might loose national slot coach dravid spot discipline iyer kishan get bcci contract condition met report http co y2kky2gvb5',
#  'condition layoff',
#  'ahmadhassanarbi 4 hour 8 comment tweet giving shut call video imagine mental health condition tout',
#  'fedup42mn overdiagnosis cancer journal national medical institute overdiagnosis term used condition diagnosed would otherwise go cause symptom death http co m2bqy8y9hb',
#  'frazzled_rip healthuncensord docdeezwhat iancopeland5 kattwilliams joerogan yea completely benign condition get point needing treated place fluoride naturally occurs water dos gt 3ppm keep f water 0 3 0 7 north america',
#  'jbygodrod agree j rod old enough remember sec one bid conference back sec tournament much fun',
#  'want conference meeting amp incentive reward program drive social impact amp deliver culturally rich experience check new first people engagement guide check http co 5nohdfz2mp background info http co vfmgoqt9o2 http co r1lecju0q1',
#  'bleacherreport chrisbhaynes brooklynnets thought stevenash problem atleast nash went eastern conference semi',
#  'talktv juliahb1 totally predictable used browder proven russiaphobe convenient yulia turned conference time carry western asset http co onv954i3u5',
#  'explore bandelier national monument host early pueblo ruin cliff dwelling national conference wilderness medicine santa fe nm may 29 june 2 2024 learn http co mygfewjtuh http co vga08xtsvv',
#  'jackyhiroller showmezou better program 100 million debt much weaker conference took pay cut come say mizzou negative arizona positive',
#  'arm higher degree research module delivered adelaide 16 april 2024 ahead qpr conference eoi accepted http co vp5b420ara http co d7uljr5pvr',
#  'carson_tk think biggest problem everyone openly shit talked dragged pac 12 thru mud call galactic change biggest brand left think football separate entity conference oregon football b1g 10',
#  'trulytexan74167 grow tired sacrament talk conference talk people prepare talk struggle find anything add prefer topical talk backed scripture snippet conference talk thought impression abridged relevant experience',
#  'top 5 eastern conference team heading star weekend http co ractfuhhh0',
#  'gswaim bring em big 12 start true 3rd power conference',
#  'caitlin clark earned big ten player week 27th time monday big ten conference history http co a1pdvde2b2',
#  'monday february 19 2024 pac 12 board director announced new commissioner taking conference http co p7pklye8pa',
#  'breakingbarriers making wave world nutrition excite da2024 conference champion positive change invited innovate advocate launch watch space big news soon learn theme http co 4fhbhkwus5 http co ubrjh0lj6x',
#  'iran taking step reshape agrifood system across asia pacific region dispatching high level delegation 37th regional conference asia pacific aprc37 held february 19 22 colombo sri lanka http co abghpeysok',
#  ...]

# %% [markdown]
# ## Sentiment Analysis with `Vader`

# %%
from nltk.sentiment.vader import SentimentIntensityAnalyzer
def analyze_sentiment(tweets, topic):
    print(f'Analyzing sentiment for topic "{topic}"')
    tweet_list = pull_topic(tweets, topic)
    sid = SentimentIntensityAnalyzer()
    # Create empty lists we can take the average of for each
    neg_list = []
    pos_list = []
    neu_list = []
    # Loop through each tweet to find the sentiments and apend to each list
    for tweet in tweet_list:
        sentiment_scores = sid.polarity_scores(tweet)
        neg_list.append(sentiment_scores['pos'])
        neu_list.append(sentiment_scores['neu'])
        pos_list.append(sentiment_scores['neg'])
    print(f'Average positive sentiment: {sum(pos_list) / len(pos_list)}')
    print(f'Average neutral sentiment: {sum(neu_list) / len(neu_list)}')
    print(f'Average negative sentiment: {sum(neg_list) / len(neg_list)}')

# %%
analyze_sentiment(text, 'Trump')
# Out:
# Analyzing sentiment for topic "Trump"
# Average positive sentiment: 0.08354761904761905
# Average neutral sentiment: 0.8376785714285714
# Average negative sentiment: 0.07876190476190476

# %%
analyze_sentiment(text, 'Biden')
# Out:
# Analyzing sentiment for topic "Biden"
# Average positive sentiment: 0.10387931034482759
# Average neutral sentiment: 0.8245
# Average negative sentiment: 0.07158620689655172

# %%
analyze_sentiment(text, 'Kamala')
# Out:
# Analyzing sentiment for topic "Kamala"
# Average positive sentiment: 0.038
# Average neutral sentiment: 0.8407777777777778
# Average negative sentiment: 0.12122222222222222

# %% [markdown]
# After analyzing Trump, Biden, and Kamala using the VADER sentiment analysis package. We can conclude that most of the tweets were considered neutral for all thre candidates. We know this cannot be entirely accurate because tweets are especially polarized during elections. We can assume that the VADER sentiment package is not picking up on the full sentiment from each tweet. By using something more advanced we can gain more insight into how each candidate is viewed.

# %% [markdown]
# ## Advanced Sentiment Analysis With Transformers

# %% [markdown]
# We used `transformers` sentiment-analysis pipeline to conduct an advanced sentiment analysis. Using this pipeline, we did not need to clean our data, because the bert model under the pipeline comes with a custom tokenizer to account for special characters and white space. The Sentiment Analysis pipeline also takes into account stop words.

# %%
from transformers import pipeline
classifier = pipeline("sentiment-analysis")
# Out:
# No model was supplied, defaulted to distilbert/distilbert-base-uncased-finetuned-sst-2-english and revision af0f99b (https://huggingface.co/distilbert/distilbert-base-uncased-finetuned-sst-2-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# config.json:   0%|          | 0.00/629 [00:00<?, ?B/s]
# C:\Users\JakeBeckman\anaconda3\Lib\site-packages\huggingface_hub\file_download.py:159: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\JakeBeckman\.cache\huggingface\hub\models--distilbert--distilbert-base-uncased-finetuned-sst-2-english. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to see activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\transformers\activations_tf.py:22
#      21 try:
# ---> 22     import tf_keras as keras
#      23 except (ModuleNotFoundError, ImportError):
#
# ModuleNotFoundError: No module named 'tf_keras'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\transformers\utils\import_utils.py:1603, in _LazyModule._get_module(self, module_name)
#    1602 try:
# -> 1603     return importlib.import_module("." + module_name, self.__name__)
#    1604 except Exception as e:
#
# File ~\anaconda3\Lib\importlib\__init__.py:90, in import_module(name, package)
#      89         level += 1
# ---> 90 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1387, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1360, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1331, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:935, in _load_unlocked(spec)
#
# File <frozen importlib._bootstrap_external>:995, in exec_module(self, module)
#
# File <frozen importlib._bootstrap>:488, in _call_with_frames_removed(f, *args, **kwds)
#
# File ~\anaconda3\Lib\site-packages\transformers\models\distilbert\modeling_tf_distilbert.py:27
#      25 import tensorflow as tf
# ---> 27 from ...activations_tf import get_tf_activation
#      28 from ...modeling_tf_outputs import (
#      29     TFBaseModelOutput,
#      30     TFMaskedLMOutput,
#    (...)
#      34     TFTokenClassifierOutput,
#      35 )
#
# File ~\anaconda3\Lib\site-packages\transformers\activations_tf.py:27
#      26     if parse(keras.__version__).major > 2:
# ---> 27         raise ValueError(
#      28             "Your currently installed version of Keras is Keras 3, but this is not yet supported in "
#      29             "Transformers. Please install the backwards-compatible tf-keras package with "
#      30             "`pip install tf-keras`."
#      31         )
#      34 def _gelu(x):
#
# ValueError: Your currently installed version of Keras is Keras 3, but this is not yet supported in Transformers. Please install the backwards-compatible tf-keras package with `pip install tf-keras`.
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# Cell In[39], line 2
#       1 from transformers import pipeline
# ----> 2 classifier = pipeline("sentiment-analysis")
#
# File ~\anaconda3\Lib\site-packages\transformers\pipelines\__init__.py:895, in pipeline(task, model, config, tokenizer, feature_extractor, image_processor, framework, revision, use_fast, token, device, device_map, torch_dtype, trust_remote_code, model_kwargs, pipeline_class, **kwargs)
#     893 if isinstance(model, str) or framework is None:
#     894     model_classes = {"tf": targeted_task["tf"], "pt": targeted_task["pt"]}
# --> 895     framework, model = infer_framework_load_model(
#     896         model,
#     897         model_classes=model_classes,
#     898         config=config,
#     899         framework=framework,
#     900         task=task,
#     901         **hub_kwargs,
#     902         **model_kwargs,
#     903     )
#     905 model_config = model.config
#     906 hub_kwargs["_commit_hash"] = model.config._commit_hash
#
# File ~\anaconda3\Lib\site-packages\transformers\pipelines\base.py:261, in infer_framework_load_model(model, config, model_classes, task, framework, **model_kwargs)
#     259         classes.append(_class)
#     260 if look_tf:
# --> 261     _class = getattr(transformers_module, f"TF{architecture}", None)
#     262     if _class is not None:
#     263         classes.append(_class)
#
# File ~\anaconda3\Lib\site-packages\transformers\utils\import_utils.py:1594, in _LazyModule.__getattr__(self, name)
#    1592 elif name in self._class_to_module.keys():
#    1593     module = self._get_module(self._class_to_module[name])
# -> 1594     value = getattr(module, name)
#    1595 else:
#    1596     raise AttributeError(f"module {self.__name__} has no attribute {name}")
#
# File ~\anaconda3\Lib\site-packages\transformers\utils\import_utils.py:1593, in _LazyModule.__getattr__(self, name)
#    1591     value = self._get_module(name)
#    1592 elif name in self._class_to_module.keys():
# -> 1593     module = self._get_module(self._class_to_module[name])
#    1594     value = getattr(module, name)
#    1595 else:
#
# File ~\anaconda3\Lib\site-packages\transformers\utils\import_utils.py:1605, in _LazyModule._get_module(self, module_name)
#    1603     return importlib.import_module("." + module_name, self.__name__)
#    1604 except Exception as e:
# -> 1605     raise RuntimeError(
#    1606         f"Failed to import {self.__name__}.{module_name} because of the following error (look up to see its"
#    1607         f" traceback):\n{e}"
#    1608     ) from e
#
# RuntimeError: Failed to import transformers.models.distilbert.modeling_tf_distilbert because of the following error (look up to see its traceback):
# Your currently installed version of Keras is Keras 3, but this is not yet supported in Transformers. Please install the backwards-compatible tf-keras package with `pip install tf-keras`.

# %% [markdown]
# The following functions filter out the topic we are interested in then run a sentiment analysis using the pipeline. `conduct_sentiment_analysis()` calls the transformers sentiment analysis pipeline, while `pull_sentiment()` brings multiple functions together to run using all tweets and a topic as parameters, returning the sentiment analysis.

# %%
def conduct_sentiment_analysis(tweets:list):
    sentiments = []
    for tweet in tweets:
        if len(tweet)>512:
            tweet = tweet[:512]
        sentiments.append(classifier(tweet)[0]['label'])
    sentiments = ' '.join(sentiments)
    positive_prop = sentiments.count('POSITIVE')/len(tweets)
    neutral_prop = sentiments.count('NEUTRAL')/len(tweets)
    negative_prop = sentiments.count('NEGATIVE')/len(tweets)
    print(f"Positive Proportion: {positive_prop}, Negative Proportion: {negative_prop}, Neutral Proportion: {neutral_prop}")
    return positive_prop,negative_prop,neutral_prop

# %%
def pull_sentiments(tweets:list,topic:str):
    tweets_ontopic = pull_topic(tweets=tweets,topic=topic)
    print(f"{len(tweets_ontopic)} tweets mention {topic}.")
    pos,neg,neu = conduct_sentiment_analysis(tweets_ontopic)
    return pos,neg,neu

# %% [markdown]
# In our project, we were interested in how certain political icons were depicted by twitter users. We focused on Joe Biden, Donald Trump, Kamala Harris, and the white house. In our analysis, we wanted to see if certain politicians were depicted better than others, and whether or not the overall sentiment of politics (using key word "white house" as our baseline) reflected the average sentiment for our candidates of interest.

# %%
pull_sentiments(text,"biden")

# %%
pos_biden = pull_sentiments(tweets=text,topic="biden")[0]
neg_biden = pull_sentiments(tweets=text,topic="biden")[1]

# %%
pos_trump=pull_sentiments(tweets=text,topic="trump")[0]
neg_trump=pull_sentiments(tweets=text,topic="trump")[1]

# %%
pos_kam=pull_sentiments(tweets=text,topic="kamala")[0]
neg_kam=pull_sentiments(tweets=text,topic="kamala")[1]

# %%
pos_wh=pull_sentiments(tweets=text,topic="white house")[0]
neg_wh=pull_sentiments(tweets=text,topic="white house")[1]

# %% [markdown]
# Our Sentiment Analysis revealed that all politicians, regardless of party, are depicted in a negative light. This makes sense as the phrase "white house" had a 100% negative sentiment label.

# %%
import matplotlib.pyplot as plt
plt.bar(height=[pos_biden,pos_trump,pos_kam,pos_wh],x=["Biden",'Trump','Kamala','White House'])
plt.bar(height=[neg_biden*-1,neg_trump*-1,neg_kam*-1,neg_wh*-1],x=["Biden",'Trump','Kamala','White House'])
plt.ylabel("Proportion Positive Sentiment")
plt.xlabel("Topic or Person")

# %%
type(text)
# Out:
# list

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans

def cluster_and_filter_relevance(texts, n_clusters=5, n_key_words=10):
    """
    Perform K-means clustering on a list of texts and filter the most relevant clusters with lemmatization.
    
    :param texts: List of texts to cluster.
    :param n_clusters: Number of clusters to create.
    :param n_key_words: Number of top keywords to use for filtering relevant clusters.
    
    :return: List of clusters with the assigned labels and a dictionary containing cluster keywords.
    """
    # Vectorize the text data
    vectorizer = TfidfVectorizer(stop_words='english')
    X = vectorizer.fit_transform(texts)
    
    # Perform K-means clustering
    kmeans = KMeans(n_clusters=n_clusters, random_state=42).fit(X)
    labels = kmeans.labels_
    
    # Initialize a dictionary to store the keywords for each cluster
    cluster_keywords = {}
    order_centroids = kmeans.cluster_centers_.argsort()[:, ::-1]
    terms = vectorizer.get_feature_names_out()
    
    # Iterate through each cluster and store the top n keywords
    for i in range(n_clusters):
        cluster_keywords[i] = [terms[ind] for ind in order_centroids[i, :n_key_words]]
    
    # Create a list of tuples containing text and its corresponding cluster label
    clustered_texts = [(text, label) for text, label in zip(texts, labels)]
    
    # Return both the list of clustered texts and the cluster_keywords dictionary
    return clustered_texts, cluster_keywords

# %%
# Example: Assuming `text` is a single string, wrap it in a list
texts = [text]  # Wrap the single string in a list

# Set n_clusters to 1 since we only have one text
clusters, keywords = cluster_and_filter_relevance(texts, n_clusters=10)

# Display the top keywords for the single cluster
print("\nCluster Keywords:")
for group, key_words in keywords.items():
    print(f"Cluster {group} keywords: {', '.join(key_words)}")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[61], line 5
#       2 texts = [text]  # Wrap the single string in a list
#       4 # Set n_clusters to 1 since we only have one text
# ----> 5 clusters, keywords = cluster_and_filter_relevance(texts, n_clusters=10)
#       7 # Display the top keywords for the single cluster
#       8 print("\nCluster Keywords:")
#
# Cell In[47], line 19, in cluster_and_filter_relevance(texts, n_clusters, n_key_words)
#      16 X = vectorizer.fit_transform(texts)
#      18 # Perform K-means clustering
# ---> 19 kmeans = KMeans(n_clusters=n_clusters, random_state=42).fit(X)
#      20 labels = kmeans.labels_
#      22 # Initialize a dictionary to store the keywords for each cluster
#
# File ~\anaconda3\Lib\site-packages\sklearn\base.py:1473, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1466     estimator._validate_params()
#    1468 with config_context(
#    1469     skip_parameter_validation=(
#    1470         prefer_skip_nested_validation or global_skip_validation
#    1471     )
#    1472 ):
# -> 1473     return fit_method(estimator, *args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1473, in KMeans.fit(self, X, y, sample_weight)
#    1438 """Compute k-means clustering.
#    1439
#    1440 Parameters
#    (...)
#    1462     Fitted estimator.
#    1463 """
#    1464 X = self._validate_data(
#    1465     X,
#    1466     accept_sparse="csr",
#    (...)
#    1470     accept_large_sparse=False,
#    1471 )
# -> 1473 self._check_params_vs_input(X)
#    1475 random_state = check_random_state(self.random_state)
#    1476 sample_weight = _check_sample_weight(sample_weight, X, dtype=X.dtype)
#
# File ~\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1414, in KMeans._check_params_vs_input(self, X)
#    1413 def _check_params_vs_input(self, X):
# -> 1414     super()._check_params_vs_input(X, default_n_init=10)
#    1416     self._algorithm = self.algorithm
#    1417     if self._algorithm == "elkan" and self.n_clusters == 1:
#
# File ~\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:878, in _BaseKMeans._check_params_vs_input(self, X, default_n_init)
#     875 def _check_params_vs_input(self, X, default_n_init=None):
#     876     # n_clusters
#     877     if X.shape[0] < self.n_clusters:
# --> 878         raise ValueError(
#     879             f"n_samples={X.shape[0]} should be >= n_clusters={self.n_clusters}."
#     880         )
#     882     # tol
#     883     self._tol = _tolerance(X, self.tol)
#
# ValueError: n_samples=1 should be >= n_clusters=10.

# %% [markdown]
# ## Works Cited

# %% [markdown]
# stackoverflow.com. Assistance given to the author, written explanation. Our group used a post from stack overflow that explained how to craete a word tokenizer that only tokenizes words, specifically, and removes special characters for us. West Point, NY 1SEP2024.
